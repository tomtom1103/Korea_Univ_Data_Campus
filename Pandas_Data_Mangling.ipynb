# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
2차원 형태의 데이터가 기본 데이터 구조다

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
데이터프레임은 어떤 구조인가?
판다스는 타 프레임워크의 장점을 파이썬으로 가져왔다.
판다스는 r의 내용을 아주 많이 참고했다!

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
칼럼이라 했는데 인덱스라 나오네?

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
type(tips['tip'])
# Out:
# pandas.core.series.Series

# %%
tips.loc[0]
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
가로세로 상관없이 1차원 데이터는 시리즈다.
맨 왼쪽, 맨 윗줄은 인덱스라고 한다.

# %%
데이터의 필수적인 기능?
select from!
가장 중요한 기능은 내가 특정 데이터를 가져오는것!
특정 데이터 가져오기전에 우리가 데이터타입을 먼저 알아야한다.
판다스는 넘파이 기반이지만 넘파이와 약간 다르다
넘파이보다 2차원 정형 데이터를 다루는데 집중했기 때문에 필요한 데이터타입을 다 없앴다.
하지만 판다스 데이터타입은 가장 중요한 명령어 info부터 봐야한다.

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
데이터타입이라고 있다. 거슬리는건 카테고리라는 데이터!
int64, float64 - 뒤에 다 64가 붙었다! 넘파이는 아주 많은 데이터타입이 있었지만
판다스는 int는 64, float 는 64가 기본이다!

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
문자열 데이터일 경우엔 object 라고 표현이 된다!
그럼 카테고리는 뭐지..?
카테고리는 몇개 안돼는 데이터로 실제 내부에서는 숫자로 관리를 한다.
오브젝트는 한정이 없는 데이터타입이고,
카테고리는 문자로 보이지만 내부적으로 숫자로 관리할 수 있는 한정된 개수의 데이터이다.

# %% [markdown]
# --------

# %%
tips.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %%
하나의 row 로 넘파이 형태로 관리를 한다!
structured array형태

# %%
tips.values[0]
# Out:
# array([16.99, 1.01, 'Female', 'No', 'Sun', 'Dinner', 2], dtype=object)

# %%
첫번째 행 이렇게 뽑으면 된다!

# %%
tips.values[0,0]
# Out:
# 16.99

# %%
첫번째 행의 첫번째 열도 이렇게 뽑을 수 있다!

# %%
tips.axes
# Out:
# [RangeIndex(start=0, stop=244, step=1),
#  Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')]

# %%
tips.memory_usage()
# Out:
# Index          128
# total_bill    1952
# tip           1952
# sex            368
# smoker         368
# day            448
# time           368
# size          1952
# dtype: int64

# %%
판다스는 하루만에 배울수 있지만
SQL은 택도없다...ㅠ

# %%
이런 다양한 정보를 조회 할 수 있는데, 기본적으로 info 함수가 제일 중요하다!

# %%
메모리 사용량 정보는 어디다가 사용 할 수 있냐?
한꺼번에 메모리에 올린다. 그럼 아주 큰 데이터는 메모리에 못올리기 때문에, 메모리에 이정도가 올라왔다라는
가이드를 통해서 내가 분산처리할지, 그냥 이 컴퓨터 한대로 처리할지 메모리함수를 보고 판단 할 수 있다

판다스는 분산처리를 할 수 있다 라는 말이다!
엑셀은 디스크 기반으로 데이터를 처리한다
1기가짜리 데이터를 사용할때, 엑셀은 너무 느리고 판다스는 빠르다!!

# %%
tips.tip
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
이렇게 특정 칼럼의 데이터도 가져올 수 있다!

# %%
tips[['tip']]
# Out:
#       tip
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# ..    ...
# 239  5.92
# 240  2.00
# 241  2.00
# 242  1.75
# 243  3.00
#
# [244 rows x 1 columns]

# %%
가로를 두개치면 팬시 인덱싱 방식으로 이렇게 이쁘게! 가져올 수 있따~
둘의 차이는 시리즈냐 데이터프레임이냐!

# %%
tips[['day','tip']]
# Out:
#       day   tip
# 0     Sun  1.01
# 1     Sun  1.66
# 2     Sun  3.50
# 3     Sun  3.31
# 4     Sun  3.61
# ..    ...   ...
# 239   Sat  5.92
# 240   Sat  2.00
# 241   Sat  2.00
# 242   Sat  1.75
# 243  Thur  3.00
#
# [244 rows x 2 columns]

# %%
이렇게 팬시 인덱싱을 사용하면 내 마음대로 구조화할 수 있다.
그리고 기본적으로 넘파이니깐, 이런거도 할 수 있다

# %%
tips.day == 'Sun'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
이렇게 불리언으로 어떤 row에 들어있는지 알 수 있다!

# %%
tips.select_dtypes('category')
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
이렇게 데이터타입별로 뽑아올 수 있다!

# %%
tips.filter(regex='^t')
# Out:
#      total_bill   tip    time
# 0         16.99  1.01  Dinner
# 1         10.34  1.66  Dinner
# 2         21.01  3.50  Dinner
# 3         23.68  3.31  Dinner
# 4         24.59  3.61  Dinner
# ..          ...   ...     ...
# 239       29.03  5.92  Dinner
# 240       27.18  2.00  Dinner
# 241       22.67  2.00  Dinner
# 242       17.82  1.75  Dinner
# 243       18.78  3.00  Dinner
#
# [244 rows x 3 columns]

# %%
이렇게 정규식을 이용해서 원하는 데이터를 뽑을수도 있다!!!
오마이갓~ 정규식 더 연습해야겟어~

# %% [markdown]
# ------------

# %%
이제 row 기반으로 데이터 추출하는법!

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips2 = tips.set_index('time')

# %%
tips2
# Out:
#         total_bill   tip     sex smoker   day  size
# time
# Dinner       16.99  1.01  Female     No   Sun     2
# Dinner       10.34  1.66    Male     No   Sun     3
# Dinner       21.01  3.50    Male     No   Sun     3
# Dinner       23.68  3.31    Male     No   Sun     2
# Dinner       24.59  3.61  Female     No   Sun     4
# ...            ...   ...     ...    ...   ...   ...
# Dinner       29.03  5.92    Male     No   Sat     3
# Dinner       27.18  2.00  Female    Yes   Sat     2
# Dinner       22.67  2.00    Male    Yes   Sat     2
# Dinner       17.82  1.75    Male     No   Sat     2
# Dinner       18.78  3.00  Female     No  Thur     2
#
# [244 rows x 6 columns]

# %%
이해를 위해서 새로운 데이터프레임 만들었다! 인덱스 재설정해서!

# %%
판다스는 인덱스가 같아도 상관없다. 이런 상황에서

# %%
tips2.iloc[-1]
# Out:
# total_bill     18.78
# tip              3.0
# sex           Female
# smoker            No
# day             Thur
# size               2
# Name: Dinner, dtype: object

# %%
tips2.iloc[3:]
# Out:
#         total_bill   tip     sex smoker   day  size
# time
# Dinner       23.68  3.31    Male     No   Sun     2
# Dinner       24.59  3.61  Female     No   Sun     4
# Dinner       25.29  4.71    Male     No   Sun     4
# Dinner        8.77  2.00    Male     No   Sun     2
# Dinner       26.88  3.12    Male     No   Sun     4
# ...            ...   ...     ...    ...   ...   ...
# Dinner       29.03  5.92    Male     No   Sat     3
# Dinner       27.18  2.00  Female    Yes   Sat     2
# Dinner       22.67  2.00    Male    Yes   Sat     2
# Dinner       17.82  1.75    Male     No   Sat     2
# Dinner       18.78  3.00  Female     No  Thur     2
#
# [241 rows x 6 columns]

# %%
넘파이 기반이니깐 슬라이싱 할 수도 있다! 인덱스 기반으로

# %%
라벨 기반은 뭘까그럼?

# %%
tips2.loc['Lunch']
# Out:
#        total_bill   tip     sex smoker   day  size
# time
# Lunch       27.20  4.00    Male     No  Thur     4
# Lunch       22.76  3.00    Male     No  Thur     2
# Lunch       17.29  2.71    Male     No  Thur     2
# Lunch       19.44  3.00    Male    Yes  Thur     2
# Lunch       16.66  3.40    Male     No  Thur     2
# ...           ...   ...     ...    ...   ...   ...
# Lunch        8.58  1.92    Male    Yes   Fri     1
# Lunch       15.98  3.00  Female     No   Fri     3
# Lunch       13.42  1.58    Male    Yes   Fri     2
# Lunch       16.27  2.50  Female    Yes   Fri     2
# Lunch       10.09  2.00  Female    Yes   Fri     2
#
# [68 rows x 6 columns]

# %%
이름으로 뽑아주는게 loc!

# %%
tips.iloc[0:3,1:4]
# Out:
#     tip     sex smoker
# 0  1.01  Female     No
# 1  1.66    Male     No
# 2  3.50    Male     No

# %%
로우, 칼럼 순으로 뽑아준다

# %%
tips.iloc[1,3]
# Out:
# 'No'

# %%
tips.iat[1,3]
# Out:
# 'No'

# %%
# %timeit tips.iloc[1,3]
# Out:
# 32 µs ± 1.52 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit tips.iat[1,3]
# Out:
# 29.3 µs ± 1.51 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# -------

# %%
방법은 엄청 많지만 원하는 값을 셀렉트하는게 가장 기본이당.
그럼 추출해서 뭐하게?
판다스가 할 수 있는게 무엇이냐!
첫번째: 데이터 처리
    데이터 불러와서 데이터값 바꾸고~
    
두번째: eda(explatory data analysis)
    간단한 통계값을 구하거나 visualization 하는것
    얘가 핵심 기능이당

# %%
이제 그래프를 그려보자
엑스축과 와이축을 뭐로 잡는지가 중요하다

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
각각의 값에 대해서 몇개가 있는지 확인할 수 있다

# %%
# Out:
# total_bill  tip    sex     smoker  day   time    size
# 13.00       2.00   Female  Yes     Thur  Lunch   2       2
# 3.07        1.00   Female  Yes     Sat   Dinner  1       1
# 22.23       5.00   Male    No      Sun   Dinner  2       1
# 20.69       2.45   Female  No      Sat   Dinner  4       1
#             5.00   Male    No      Sun   Dinner  5       1
#                                                         ..
# 15.53       3.00   Male    Yes     Sat   Dinner  2       1
# 15.69       1.50   Male    Yes     Sun   Dinner  2       1
#             3.00   Male    Yes     Sat   Dinner  3       1
# 15.77       2.23   Female  No      Sat   Dinner  2       1
# 50.81       10.00  Male    Yes     Sat   Dinner  3       1
# Length: 243, dtype: int64

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips['total_bill'].value_counts()
# Out:
# 13.42    3
# 21.01    2
# 18.29    2
# 10.07    2
# 20.69    2
#         ..
# 24.27    1
# 38.07    1
# 7.51     1
# 14.52    1
# 26.88    1
# Name: total_bill, Length: 229, dtype: int64

# %%
밸류 카운트 자체도 중요하지만 인덱스가 어떻게 표현되는지가 중요한거다!!
여기서 이거 결과!! 비쥬얼라이제이션 하고싶다! 하면?
판다스의 장점! 외우자!
그래프 그릴때 index 가 x축이다!

# %%
tips.sex.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
내가 원하는 값을 뽑아서 통계값을 뽑거나 보여줄수 있따!

# %%
tips.sex.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
tips.day.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
내가 필요한 데이터를 가지고 비쥬얼라이제이션 아주 빨리 할 수 있따
근데 여기서 거슬리는건? 이거 맷플롯립 그래프다
맷플롯립그래프를 판다스에서 쉽게 사용할 수 있게한거당

# %%
import matplotlib.pyplot as plt

# %%
plt.title('test')
tips.day.value_counts().plot.bar()
# Out:
# <AxesSubplot:title={'center':'test'}>

# %%
우왕! 연동된다!!
판다스 명령어 쓰고 커스터마이징 하고싶으면 맷플롯립 기능 추가하면 된당~

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
각각 데이터 몇개씩 있는지 알고싶어!

# %%
iris.species.value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
plt.title('test')
iris.species.value_counts().plot.bar()
# Out:
# <AxesSubplot:title={'center':'test'}>

# %%
세팔 관련 데이터만 뽑아서 그래프 그린거처럼 하고싶다

# %%
iris.filter(regex='^sepal')
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
iris.filter(regex='^sepal').max()
# Out:
# sepal_length    7.9
# sepal_width     4.4
# dtype: float64

# %%
iris.filter(regex='^sepal').min()
# Out:
# sepal_length    4.3
# sepal_width     2.0
# dtype: float64

# %%
iris.filter(regex='^sepal').describe()
# Out:
#        sepal_length  sepal_width
# count    150.000000   150.000000
# mean       5.843333     3.057333
# std        0.828066     0.435866
# min        4.300000     2.000000
# 25%        5.100000     2.800000
# 50%        5.800000     3.000000
# 75%        6.400000     3.300000
# max        7.900000     4.400000

# %%
이거 그래프 그려주세용!

# %%
iris.filter(regex='^sepal').describe().plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.filter(regex='^sepal').describe().loc[['count','mean']]
# Out:
#        sepal_length  sepal_width
# count    150.000000   150.000000
# mean       5.843333     3.057333

# %%
iris.filter(regex='^sepal').describe().loc[['count','mean']].plot.bar()
# Out:
# <AxesSubplot:>

# %%
레전드까지 붙혀준다. 판다스는 레전드다..

# %%
판다스의 주 활용처 - 내가 원하는 기능을 뽑아서 통계값 뽑고 그래프 그리고~
그래프는 맷플롯립기반이당
짜! 이제 두번째 주제로 넘어갑니당~

# %% [markdown]
# -----------

# %%
판다스는 데이터 처리하고 내가 원하는 결과값 뽑아서 통계값, 그래프 그릴수도 있다

# %%
두번째 주제는 데이터 처리!!!!!!가슴이 웅장해진다

# %%
우리 저저번주에 뭐했지? 함수형 패러다임 사용해서 빠르고 편하게 쉽게 데이터처리하는거 했자나~
야! 까먹으면 안대!!

# %%
dir(tips)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
x = iter(tips)

# %%
for i in tips:
    print(i)
# Out:
# total_bill
# tip
# sex
# smoker
# day
# time
# size

# %%
이터레이터, 제너레이터, 컴프리헨션, 맵필터, 리듀스 등등~
이동네 왕은 맵이당

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
성별을 남자를 m 여자를 f 로 바꿀게요!!

# %%
tips.sex.map({'Female': 'F','Male':'M'})
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['M', 'F']

# %%
tips.tip.map(lambda x:x-1)
# Out:
# 0      0.01
# 1      0.66
# 2      2.50
# 3      2.31
# 4      2.61
#        ...
# 239    4.92
# 240    1.00
# 241    1.00
# 242    0.75
# 243    2.00
# Name: tip, Length: 244, dtype: float64

# %%
데이터처리 이렇게 할수도 있구나~

# %%
tips.tip.mean()
# Out:
# 2.9982786885245902

# %%
tips.tip.std()
# Out:
# 1.3836381890011826

# %%
tips.tip.map(lambda x: (x-tips.tip.mean())/tips.tip.std())
# Out:
# 0     -1.436993
# 1     -0.967217
# 2      0.362610
# 3      0.225291
# 4      0.442111
#          ...
# 239    2.111622
# 240   -0.721488
# 241   -0.721488
# 242   -0.902171
# 243    0.001244
# Name: tip, Length: 244, dtype: float64

# %%
이렇게 표준화할수도 있따!!
여기 겁나중요하네

# %%
이런걸 data wrangling/munging 이라 한당.
판다스 자체는 데이터 맹글링 툴이다!
아~ 이런거구나~
이걸로 통계분석 하고싶다! 그럼 statsmodel 로 넘기면 된다!
싸이킷으로 넘겨!
딥러닝하고싶음 텐서플로우로 넘겨!
다~~~연동이 된다!
시계열하고싶음 fbprophet 으로 넘겨!

# %%
기계학습 전 과정에서 데이터 전처리가 제일 많이 걸린다ㅠ

# %% [markdown]
# -------------

# %%
판다스 핵심키워드 다시 정리하면!
판다스는 데이터 랭글링 툴이다.데이터를 입력 받아서 간단한 전처리를 하고
이 전처리를 통한 간단한 분석을 하는 것 - 데이터 랭글링이다!
판다스는 기존의 엑셀이나 sql과 비교했을땐, 엑셀보단 어렵지만 굉장히 효율적이다!
메모리에 올려서 처리하기 때문에 엑셀과 비교할 수 없을 정도로 빠르다.

토요일날 깃 배웠었다! 깃 버젼관리, 엑셀로 사용할땐 버젼관리가 힘들다.
판다스는 깃으로 버젼관리 할 수 있다. 파이썬이니깐~
속도빠르고, 버젼관리되고..

SQL은 다된다. 속도도 빠르고 판다스에서 할수있는거 다할수있다
근데 SQL은 어렵당ㅠ 툴 배우는데 시간 다 간다. 활용에 목적을 둬야하는뎅..
판다스는 이 역할자체는 애매하지만 우리한테 데이터 기반으로 분석 예측하고자 하는 사람들한테는
정말 딱 맞는 도구다.

# %%
이제부터 본게임.

# %%
데이터 처리는 두가지 관점에서 봐야한다
구조적 처리와 데이터 값 자체

구조적 문제는 어떤 문제일까?
논문 확인해볼게유!

# %%
데이터 구조를 바꾸는데 시간이 엄청 걸린다ㅠㅠ

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
aggregation 형태 - 이런 형태로 구성하면 aggregation 하기 쉽다

# %%
성별로 aggregation 해보자!

# %%
tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
통계값이기 때문에 숫자만 나온다
남녀의 전체 식사비, 팁
사이즈는 안중요하니깐

# %%
tips.groupby('sex').mean()[['total_bill','tip']]
# Out:
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
x축이 인덱스다

# %%
tips.groupby('sex').mean()[['total_bill','tip']].plot.bar()
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
그래프 그리기 쉽네~

# %%
tips.groupby('sex').mean()[['total_bill','tip']].plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
데이터 수집 칼럼 잡을때 이런 형태로 안만들었을 가능성이 크다
칼럼 잘 잡아야한당..
칼럼 자체가 성별이 되도록 하면 안된다..

# %%
논문에 있는 예시로 실습해보자!

# %% [markdown]
# -------------

# %% [markdown]
# --------

# %%
데이터 처리는
    구조적 변경
    데이터 값 변경
    
이 있는데, 먼저 구조적 변경을 해보자~

# %%
pew = pd.read_csv('pew.txt')

# %%
pew
# Out:
#    religion\t"<$10k"\t"$10-20k"\t"$20-30k"\t"$30-40k"\t"$40-50k"\t"$50-75k"\t"$75-100k"\t"$100-150k"\t">150k"\t"Don't know/refused"
# 0   Agnostic\t27\t34\t60\t81\t76\t137\t122\t109\t8...
# 1     Atheist\t12\t27\t37\t52\t35\t70\t73\t59\t74\t76
# 2    Buddhist\t27\t21\t30\t34\t33\t58\t62\t39\t53\t54
# 3   Catholic\t418\t617\t732\t670\t638\t1116\t949\t...
# 4   Don’t know/refused\t15\t14\t15\t11\t10\t35\t21...
# 5   Evangelical Prot\t575\t869\t1064\t982\t881\t14...
# 6           Hindu\t1\t9\t7\t9\t11\t34\t47\t48\t54\t37
# 7   Historically Black Prot\t228\t244\t236\t238\t1...
# 8   Jehovah's Witness\t20\t27\t24\t24\t21\t30\t15\...
# 9    Jewish\t19\t19\t25\t25\t30\t95\t69\t87\t151\t162
# 10  Mainline Prot\t289\t495\t619\t655\t651\t1107\t...
# 11    Mormon\t29\t40\t48\t51\t56\t112\t85\t49\t42\t69
# 12           Muslim\t6\t7\t9\t10\t9\t23\t16\t8\t6\t22
# 13   Orthodox\t13\t17\t23\t32\t32\t47\t38\t42\t46\t73
# 14  Other Christian\t9\t7\t11\t13\t13\t14\t18\t14\...
# ...

# %%
판다스는 정형 데이터다. 비정형데이터는 hdf 형태로 저장할 수 있다
기본적으로 정형데이터만 불러올수 있다
html json 반정형데이터! 얘는 정형화 할 수 있으면 불러와도 된다

# %%
칼럼에 구분이 안되어있다ㅠ 이건 \t로 분리가 되어있는 데이턴데, 하나로 인식한거다
그래서 나눠줘야한다!

# %%
pew = pd.read_csv('pew.txt', sep='\t')

# %%
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
이런 데이터. 문제있다
수익 컬럼 안에 하위 요소로 들어가야한다.
사용할수 있지만 다른 방법이 더 좋다!
어떻게해야할까낭~~호잇호잇

# %%
이런식으로 데이터가 칼럼이 기니깐 '와이드'하다고 한다. 와이드 포맷이라고 하는사람들더 있당
와이드 포맷을 밑으로 길게 롱포맷으로 바꿔줄수 있다
그럼 데이터 삭제할때도 편하다
이럴땐 melt!

# %%
pew.melt('religion')
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
pew.melt('religion',var_name='moon',value_name='star')
# Out:
#                   religion                moon  star
# 0                 Agnostic               <$10k    27
# 1                  Atheist               <$10k    12
# 2                 Buddhist               <$10k    27
# 3                 Catholic               <$10k   418
# 4       Don’t know/refused               <$10k    15
# ..                     ...                 ...   ...
# 175               Orthodox  Don't know/refused    73
# 176        Other Christian  Don't know/refused    18
# 177           Other Faiths  Don't know/refused    71
# 178  Other World Religions  Don't know/refused     8
# 179           Unaffiliated  Don't know/refused   597
#
# [180 rows x 3 columns]

# %%
오.. 이름도 바꿔줄수도 있넹!

# %%
pew_tidy = pew.melt('religion')

# %%
pew_tidy.rename({'variable':'moon','value':'star'},axis=1)
# Out:
#                   religion                moon  star
# 0                 Agnostic               <$10k    27
# 1                  Atheist               <$10k    12
# 2                 Buddhist               <$10k    27
# 3                 Catholic               <$10k   418
# 4       Don’t know/refused               <$10k    15
# ..                     ...                 ...   ...
# 175               Orthodox  Don't know/refused    73
# 176        Other Christian  Don't know/refused    18
# 177           Other Faiths  Don't know/refused    71
# 178  Other World Religions  Don't know/refused     8
# 179           Unaffiliated  Don't know/refused   597
#
# [180 rows x 3 columns]

# %%
pew_tidy.rename(columns={'variable':'moon','value':'star'})
# Out:
#                   religion                moon  star
# 0                 Agnostic               <$10k    27
# 1                  Atheist               <$10k    12
# 2                 Buddhist               <$10k    27
# 3                 Catholic               <$10k   418
# 4       Don’t know/refused               <$10k    15
# ..                     ...                 ...   ...
# 175               Orthodox  Don't know/refused    73
# 176        Other Christian  Don't know/refused    18
# 177           Other Faiths  Don't know/refused    71
# 178  Other World Religions  Don't know/refused     8
# 179           Unaffiliated  Don't know/refused   597
#
# [180 rows x 3 columns]

# %%
이렇게 argument를 변환해서 방법이 많다!!!
axis 0은 인덱스,
axis 1은 칼럼!!!!

파이썬은 shallowcopy
numpy 는 deepcopy

리턴이 없으면 자기 자신이 변하고
리턴이 있으면 안변한다!!

inplace=True로 하면
mutable 로 사용할 수 있다 = 결과가 없어지니 재할당이 되는거당!!

# %%
pew_tidy.rename(columns={'variable':'moon','value':'star'},inplace=True)

# %%
pew_tidy
# Out:
#                   religion                moon  star
# 0                 Agnostic               <$10k    27
# 1                  Atheist               <$10k    12
# 2                 Buddhist               <$10k    27
# 3                 Catholic               <$10k   418
# 4       Don’t know/refused               <$10k    15
# ..                     ...                 ...   ...
# 175               Orthodox  Don't know/refused    73
# 176        Other Christian  Don't know/refused    18
# 177           Other Faiths  Don't know/refused    71
# 178  Other World Religions  Don't know/refused     8
# 179           Unaffiliated  Don't know/refused   597
#
# [180 rows x 3 columns]

# %%
원본 바뀌었다!!!

# %% [markdown]
# --------------------

# %%
점심시간~.~

# %% [markdown]
# ----------

# %%
만약 멜트가 없었으면?
구조변경하는건 몇가지가 있을까?

# %%
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
인덱스를 변경한다는것은 특정 데이터를 특정 칼럼으로 변환하는것!

# %%
pew.set_index('religion')
# Out:
#                          <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# religion
# Agnostic                    27       34       60       81       76      137
# Atheist                     12       27       37       52       35       70
# Buddhist                    27       21       30       34       33       58
# Catholic                   418      617      732      670      638     1116
# Don’t know/refused          15       14       15       11       10       35
# Evangelical Prot           575      869     1064      982      881     1486
# Hindu                        1        9        7        9       11       34
# Historically Black Prot    228      244      236      238      197      223
# Jehovah's Witness           20       27       24       24       21       30
# Jewish                      19       19       25       25       30       95
# Mainline Prot              289      495      619      655      651     1107
# ...

# %%
index/stack/unstack
이해가 깊으면 멜트가 없어도 할 수 있다!
그럼 이게 뭔가?
스택은 컬럼의 내용을 인덱스로 바꾸는것!
언스택은 거꾸로

# %%
pew.set_index('religion').stack()
# Out:
# religion
# Agnostic      <$10k                  27
#               $10-20k                34
#               $20-30k                60
#               $30-40k                81
#               $40-50k                76
#                                    ...
# Unaffiliated  $50-75k               528
#               $75-100k              407
#               $100-150k             321
#               >150k                 258
#               Don't know/refused    597
# Length: 180, dtype: int64

# %%
이거 모양 잘보니깐 멜트와 비슷하다!

# %%
pew.set_index('religion').stack().reset_index()
# Out:
#          religion             level_1    0
# 0        Agnostic               <$10k   27
# 1        Agnostic             $10-20k   34
# 2        Agnostic             $20-30k   60
# 3        Agnostic             $30-40k   81
# 4        Agnostic             $40-50k   76
# ..            ...                 ...  ...
# 175  Unaffiliated             $50-75k  528
# 176  Unaffiliated            $75-100k  407
# 177  Unaffiliated           $100-150k  321
# 178  Unaffiliated               >150k  258
# 179  Unaffiliated  Don't know/refused  597
#
# [180 rows x 3 columns]

# %%
pew.melt('religion')
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
멀티인덱스!

# %%
pew.set_index('religion').stack() 이건 1차원이고, 리셋 인덱스를 하면 2차원으로 다시 만들어주는것

# %%
pew.set_index('religion').stack().reset_index().sort_values('level_1')
# Out:
#               religion             level_1    0
# 81   Jehovah's Witness             $10-20k   27
# 111             Mormon             $10-20k   40
# 21            Buddhist             $10-20k   21
# 91              Jewish             $10-20k   19
# 121             Muslim             $10-20k    7
# ..                 ...                 ...  ...
# 29            Buddhist  Don't know/refused   54
# 19             Atheist  Don't know/refused   76
# 9             Agnostic  Don't know/refused   96
# 159       Other Faiths  Don't know/refused   71
# 179       Unaffiliated  Don't know/refused  597
#
# [180 rows x 3 columns]

# %%
셋 인덱스는 특정 칼럼을 인덱스로 바꾸는것.
리셋 인덱스는 다시 0부터 시작되는 인덱스를 바꾸는것!

# %%
pew.set_index('religion').reset_index(drop=True)
# Out:
#     <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  $75-100k  $100-150k  \
# 0      27       34       60       81       76      137       122        109
# 1      12       27       37       52       35       70        73         59
# 2      27       21       30       34       33       58        62         39
# 3     418      617      732      670      638     1116       949        792
# 4      15       14       15       11       10       35        21         17
# 5     575      869     1064      982      881     1486       949        723
# 6       1        9        7        9       11       34        47         48
# 7     228      244      236      238      197      223       131         81
# 8      20       27       24       24       21       30        15         11
# 9      19       19       25       25       30       95        69         87
# 10    289      495      619      655      651     1107       939        753
# ...

# %%
그럼 릴리전이란 칼럼을 없애는것!

# %%
흠냐.. 리뷰가 꼭 필요하겟다 이건 좀 어렵다

# %% [markdown]
# --------

# %%
판다스 테크닉 좀만 더 해보쟝.

# %%
pew.melt(['religion'])
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
리스트 형태로 받을수도 있다

# %% [markdown]
# ------

# %%
두번째 예시!

# %%
billboard = pd.read_csv('billboard.csv')

# %%
billboard
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
# ...

# %%
태생적으로 와이드 포맷은 NaN 데이터가 많을수도 있다.
그럼 고정시킬걸 찾아서

# %%
billboard.columns[:7]
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked'],
#       dtype='object')

# %%
billboard.melt(billboard.columns[:7])
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...     ...                  ...                                    ...   ...
# 24087  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 24088  2000          Smith, Will                            Freakin' It  3:58
# 24089  2000        Zombie Nation                          Kernkraft 400  3:30
# 24090  2000       Eastsidaz, The                               Got Beef  3:58
# 24091  2000               Fragma                         Toca's Miracle  3:22
#
# ...

# %%
칼럼수를 확 줄여줄수 있네!
근데 문제가 좀 있네?

# %%
billboard_melt = billboard.melt(billboard.columns[:7])

# %%
billboard_melt.year.value_counts()
# Out:
# 2000    24092
# Name: year, dtype: int64

# %%
모든 데이터가 똑같다.. year은 없애도 되네?
그리고 또 거슬리는거
1주차 2주차 너무 거슬린당
이거 어떻게하면될까?
구조 바꾸는건 별거없다

set_index, reset_index, stack, unstack, melt, pivot = 구조 바꾸는건 이거면 된다! sci!

근본적인 질문이 있네? 데이터 수집할때부터 그냥 잘하면 되지않냐? 설계잘하면 구조 바꿀필요도 없는데..
근데 설계 엉터리로 해도 언제든지 바꿀수 있다! 둘다 잘하면 된다~

그럼 내용 바꾸는거 해봐야징~

# %%
여기서 뭘뽑아내야하지? 숫자만 뽑아내면 몇주인지 할 수 있다

# %%
billboard_melt.variable
# Out:
# 0         x1st.week
# 1         x1st.week
# 2         x1st.week
# 3         x1st.week
# 4         x1st.week
#             ...
# 24087    x76th.week
# 24088    x76th.week
# 24089    x76th.week
# 24090    x76th.week
# 24091    x76th.week
# Name: variable, Length: 24092, dtype: object

# %%
여기서 숫자만 뽑으면 된당
판다스의 맵은 시리즈에 쓸 수 있다

# %%
billboard_melt.variable.map(lambda x:x[1:-7])
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 24087    76
# 24088    76
# 24089    76
# 24090    76
# 24091    76
# Name: variable, Length: 24092, dtype: object

# %%
이렇게 하면 숫자만 뽑아낼 수 있네! 아유깔끔해~
이런식으로 있고,
맵이 너무 어려우면? 어떤 기능을 제공해주냐?

# %%
billboard_melt.variable.dtype
# Out:
# dtype('O')

# %%
오브젝트라는 뜻이다!
문자열일 경우,사용할수 있는 기능들이 있땅

# %%
import re

# %%
billboard_melt.variable.str.extract(r'(\d+)',expand=False)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 24087    76
# 24088    76
# 24089    76
# 24090    76
# 24091    76
# Name: variable, Length: 24092, dtype: object

# %%
이렇게 정규식으로 뽑을 수 있따! 또 이렇게 정규식이 나오네... 어렵다

# %%
billboard_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             24092 non-null  int64
#  1   artist.inverted  24092 non-null  object
#  2   track            24092 non-null  object
#  3   time             24092 non-null  object
#  4   genre            24092 non-null  object
#  5   date.entered     24092 non-null  object
#  6   date.peaked      24092 non-null  object
#  7   variable         24092 non-null  object
#  8   value            5307 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.7+ MB

# %%
import datetime

# %%
이건 시계열데이터 처리할때도 사용할 수 있따!

# %%
billboard_melt['date.entered'] = pd.to_datetime(billboard_melt['date.entered'])

# %%
billboard_melt
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...     ...                  ...                                    ...   ...
# 24087  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 24088  2000          Smith, Will                            Freakin' It  3:58
# 24089  2000        Zombie Nation                          Kernkraft 400  3:30
# 24090  2000       Eastsidaz, The                               Got Beef  3:58
# 24091  2000               Fragma                         Toca's Miracle  3:22
#
# ...

# %%
billboard_melt.set_index('date.entered').dropna()[['value']].plot.line()
# Out:
# <AxesSubplot:xlabel='date.entered'>

# %% [markdown]
# ---------------------------

# %%
tb = pd.read_csv('tb.csv')

# %%
tb
# Out:
#      iso2  year   new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0      AD  1989      NaN         NaN          NaN          NaN           NaN
# 1      AD  1990      NaN         NaN          NaN          NaN           NaN
# 2      AD  1991      NaN         NaN          NaN          NaN           NaN
# 3      AD  1992      NaN         NaN          NaN          NaN           NaN
# 4      AD  1993     15.0         NaN          NaN          NaN           NaN
# ...   ...   ...      ...         ...          ...          ...           ...
# 5764   ZW  2004  14581.0         NaN          NaN        187.0         833.0
# 5765   ZW  2005  13155.0         NaN          NaN        210.0         837.0
# 5766   ZW  2006  12718.0         NaN          NaN        215.0         736.0
# 5767   ZW  2007  10583.0         6.0        132.0        138.0         500.0
# 5768   ZW  2008   9830.0         NaN          NaN        127.0         614.0
#
# ...

# %%
야씨 이거 다 똑같은 내용인데 칼럼으로 줄일수 있겟넹?
뭐만 고정시키고? Iso2 랑 year!

# %%
tb.melt(['iso2','year'])
# Out:
#        iso2  year   variable  value
# 0        AD  1989     new_sp    NaN
# 1        AD  1990     new_sp    NaN
# 2        AD  1991     new_sp    NaN
# 3        AD  1992     new_sp    NaN
# 4        AD  1993     new_sp   15.0
# ...     ...   ...        ...    ...
# 121144   ZW  2004  new_sp_fu    NaN
# 121145   ZW  2005  new_sp_fu    NaN
# 121146   ZW  2006  new_sp_fu    NaN
# 121147   ZW  2007  new_sp_fu    NaN
# 121148   ZW  2008  new_sp_fu    0.0
#
# [121149 rows x 4 columns]

# %%
이제 필요없는 데이터 없애버리자!

# %%
판다스의 드랍은 sql의 드랍처럼 없애버린다!
위험한칭구넹~
없앨수있는건 3개!

drop_na 미싱데이터 없앨때!
drop 칼럼 없앨때
drop_duplicates 중복데이터 없앨때

# %%
데이터가 작으면 미싱데이터를 다른 값으로 채워야한다
근데 얜 구조적으로 직사각형 형태로 만들었기 때문에 어쩔수 없이 생기는 미싱데이터 - 결측치다!
이런건 무조건 없애야된다.

# %%
tb.melt(['iso2','year']).dropna()
# Out:
#        iso2  year   variable  value
# 4        AD  1993     new_sp   15.0
# 5        AD  1994     new_sp   24.0
# 6        AD  1996     new_sp    8.0
# 7        AD  1997     new_sp   17.0
# 8        AD  1998     new_sp    1.0
# ...     ...   ...        ...    ...
# 120964   VU  2008  new_sp_fu    0.0
# 121038   YE  2008  new_sp_fu    0.0
# 121092   ZA  2008  new_sp_fu    0.0
# 121119   ZM  2008  new_sp_fu    0.0
# 121148   ZW  2008  new_sp_fu    0.0
#
# [38619 rows x 4 columns]

# %%
확 줄었네! 근데 인덱스가 사이사이 비었네..? 이럴땐 reset index!

# %%
tb_melt = tb.melt(['iso2','year']).dropna().reset_index(drop=True)
tb_melt
# Out:
#       iso2  year   variable  value
# 0       AD  1993     new_sp   15.0
# 1       AD  1994     new_sp   24.0
# 2       AD  1996     new_sp    8.0
# 3       AD  1997     new_sp   17.0
# 4       AD  1998     new_sp    1.0
# ...    ...   ...        ...    ...
# 38614   VU  2008  new_sp_fu    0.0
# 38615   YE  2008  new_sp_fu    0.0
# 38616   ZA  2008  new_sp_fu    0.0
# 38617   ZM  2008  new_sp_fu    0.0
# 38618   ZW  2008  new_sp_fu    0.0
#
# [38619 rows x 4 columns]

# %%
이렇게 구조 바꾸고 정리할 수 있다!!
근데 문제 또있네?ㅋㅋ

# %%
tb_melt.variable.value_counts()
# Out:
# new_sp          3067
# new_sp_m4554    2407
# new_sp_m3544    2401
# new_sp_m5564    2400
# new_sp_m2534    2394
# new_sp_m65      2394
# new_sp_m1524    2393
# new_sp_f4554    2387
# new_sp_f2534    2386
# new_sp_f3544    2384
# new_sp_f65      2382
# new_sp_f1524    2380
# new_sp_f5564    2380
# new_sp_m014     2367
# new_sp_f014     2364
# new_sp_f514      404
# new_sp_m514      401
# new_sp_f04       393
# new_sp_m04       392
# new_sp_mu        272
# new_sp_fu        271
# Name: variable, dtype: int64

# %%
데이터 진짜 무식하게 만들었네? 구조 바꿔야되겟네..? 후
성별 칼럼 만들어야겟네... 시발ㄹㄹㄹ
새로운 칼럼 만드는법

# %%
tb.columns
# Out:
# Index(['iso2', 'year', 'new_sp', 'new_sp_m04', 'new_sp_m514', 'new_sp_m014',
#        'new_sp_m1524', 'new_sp_m2534', 'new_sp_m3544', 'new_sp_m4554',
#        'new_sp_m5564', 'new_sp_m65', 'new_sp_mu', 'new_sp_f04', 'new_sp_f514',
#        'new_sp_f014', 'new_sp_f1524', 'new_sp_f2534', 'new_sp_f3544',
#        'new_sp_f4554', 'new_sp_f5564', 'new_sp_f65', 'new_sp_fu'],
#       dtype='object')

# %%
tb['iso2']
# Out:
# 0       AD
# 1       AD
# 2       AD
# 3       AD
# 4       AD
#         ..
# 5764    ZW
# 5765    ZW
# 5766    ZW
# 5767    ZW
# 5768    ZW
# Name: iso2, Length: 5769, dtype: object

# %%
x = {'a':1,'b':2}

# %%
x['c']=3

# %%
x
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
tb_melt
# Out:
#       iso2  year   variable  value
# 0       AD  1993     new_sp   15.0
# 1       AD  1994     new_sp   24.0
# 2       AD  1996     new_sp    8.0
# 3       AD  1997     new_sp   17.0
# 4       AD  1998     new_sp    1.0
# ...    ...   ...        ...    ...
# 38614   VU  2008  new_sp_fu    0.0
# 38615   YE  2008  new_sp_fu    0.0
# 38616   ZA  2008  new_sp_fu    0.0
# 38617   ZM  2008  new_sp_fu    0.0
# 38618   ZW  2008  new_sp_fu    0.0
#
# [38619 rows x 4 columns]

# %%
여기 배리어블 완전 엉터리다.

# %%
tb_melt['sex'] = 0

# %%
tb_melt
# Out:
#       iso2  year   variable  value  sex
# 0       AD  1993     new_sp   15.0    0
# 1       AD  1994     new_sp   24.0    0
# 2       AD  1996     new_sp    8.0    0
# 3       AD  1997     new_sp   17.0    0
# 4       AD  1998     new_sp    1.0    0
# ...    ...   ...        ...    ...  ...
# 38614   VU  2008  new_sp_fu    0.0    0
# 38615   YE  2008  new_sp_fu    0.0    0
# 38616   ZA  2008  new_sp_fu    0.0    0
# 38617   ZM  2008  new_sp_fu    0.0    0
# 38618   ZW  2008  new_sp_fu    0.0    0
#
# [38619 rows x 5 columns]

# %%
브로드캐스팅 지원하기때문에 이게 가능한거다!
근데 문제가 생겼네.. 우선 성별 없는놈 없애버리자

# %%
tb.drop('new_sp', axis=1, inplace=True)

# %%
tb
# Out:
#      iso2  year  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0      AD  1989         NaN          NaN          NaN           NaN
# 1      AD  1990         NaN          NaN          NaN           NaN
# 2      AD  1991         NaN          NaN          NaN           NaN
# 3      AD  1992         NaN          NaN          NaN           NaN
# 4      AD  1993         NaN          NaN          NaN           NaN
# ...   ...   ...         ...          ...          ...           ...
# 5764   ZW  2004         NaN          NaN        187.0         833.0
# 5765   ZW  2005         NaN          NaN        210.0         837.0
# 5766   ZW  2006         NaN          NaN        215.0         736.0
# 5767   ZW  2007         6.0        132.0        138.0         500.0
# 5768   ZW  2008         NaN          NaN        127.0         614.0
#
#       new_sp_m2534  new_sp_m3544  new_sp_m4554  new_sp_m5564  ...  new_sp_f04  \
# ...

# %%
tb_melt = tb.melt(['iso2','year']).dropna().reset_index(drop=True)

# %%
tb_melt
# Out:
#       iso2  year    variable  value
# 0       AD  2005  new_sp_m04    0.0
# 1       AD  2006  new_sp_m04    0.0
# 2       AD  2008  new_sp_m04    0.0
# 3       AE  2006  new_sp_m04    0.0
# 4       AE  2007  new_sp_m04    0.0
# ...    ...   ...         ...    ...
# 35547   VU  2008   new_sp_fu    0.0
# 35548   YE  2008   new_sp_fu    0.0
# 35549   ZA  2008   new_sp_fu    0.0
# 35550   ZM  2008   new_sp_fu    0.0
# 35551   ZW  2008   new_sp_fu    0.0
#
# [35552 rows x 4 columns]

# %%
이렇게 체이닝으로 한번에 만들 수 있다!

# %%
tb_melt.variable.str.replace('new_sp_','').str[0]
# Out:
# 0        m
# 1        m
# 2        m
# 3        m
# 4        m
#         ..
# 35547    f
# 35548    f
# 35549    f
# 35550    f
# 35551    f
# Name: variable, Length: 35552, dtype: object

# %%
new_sp_라는 스트링을 ''로 바꾸고, 첫번째 문자열만 재할당하면 m, f 만 뽑아낼 수 있다.
개쩐다리

# %%
tb_melt.variable.str[7:8]
# Out:
# 0        m
# 1        m
# 2        m
# 3        m
# 4        m
#         ..
# 35547    f
# 35548    f
# 35549    f
# 35550    f
# 35551    f
# Name: variable, Length: 35552, dtype: object

# %%
이렇게 뽑을수도 있고

# %%
tb_melt['sex'] = tb_melt.variable.str[7:8]

# %%
tb_melt
# Out:
#       iso2  year    variable  value sex
# 0       AD  2005  new_sp_m04    0.0   m
# 1       AD  2006  new_sp_m04    0.0   m
# 2       AD  2008  new_sp_m04    0.0   m
# 3       AE  2006  new_sp_m04    0.0   m
# 4       AE  2007  new_sp_m04    0.0   m
# ...    ...   ...         ...    ...  ..
# 35547   VU  2008   new_sp_fu    0.0   f
# 35548   YE  2008   new_sp_fu    0.0   f
# 35549   ZA  2008   new_sp_fu    0.0   f
# 35550   ZM  2008   new_sp_fu    0.0   f
# 35551   ZW  2008   new_sp_fu    0.0   f
#
# [35552 rows x 5 columns]

# %%
이렇게 재할당 할 수 있따!!!!!!!!
예!!!!!!!!!!!!!!!!!!!!!!

# %%
기본적으로 분석하기 좋은 형태로 구조를 변화시켜야한다
설계 잘해서 데이터 수집할때부터 잘 만들어놓으면 이런 노가다 안해도 된다
근데 현실은 그렇지 않다.. 왜?
가장 어려운게 설계고, 설계는 항상 바뀌길 마련이다

멜트가 제일 중요하넹?

# %% [markdown]
# -----------------

# %%
쉬는시간! 세시 이십분까지~

# %% [markdown]
# -----------

# %%
tips = sns.load_dataset('tips')

# %%
aggregation 3총사
groupby, crosstab, pivot_table

# %%
t = tips.groupby('sex')

# %%
dir(t)
# Out:
# ['__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_agg_examples_doc',
#  '_agg_general',
#  '_aggregate_frame',
#  '_aggregate_item_by_item',
#  '_aggregate_with_numba',
#  '_apply_allowlist',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_assure_grouper',
#  '_bool_agg',
#  '_builtin_table',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_blocks',
#  '_cython_agg_general',
# ...

# %%
__iter__ 가 있다!

# %%
s = iter(t)

# %%
next(s)
# Out:
# ('Female',
#       total_bill   tip     sex smoker   day    time  size
#  0         16.99  1.01  Female     No   Sun  Dinner     2
#  4         24.59  3.61  Female     No   Sun  Dinner     4
#  11        35.26  5.00  Female     No   Sun  Dinner     4
#  14        14.83  3.02  Female     No   Sun  Dinner     2
#  16        10.33  1.67  Female     No   Sun  Dinner     3
#  ..          ...   ...     ...    ...   ...     ...   ...
#  226       10.09  2.00  Female    Yes   Fri   Lunch     2
#  229       22.12  2.88  Female    Yes   Sat  Dinner     2
#  238       35.83  4.67  Female     No   Sat  Dinner     3
#  240       27.18  2.00  Female    Yes   Sat  Dinner     2
#  243       18.78  3.00  Female     No  Thur  Dinner     2
#
#  [87 rows x 7 columns])

# %%
그룹을 해서 데이터를 이렇게 만들어준다!

# %%
이게 바로 SAC 기법이다 (spilt apply combine)!!

# %%
for i in t:
    print(i)
# Out:
# ('Male',      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns])
# ('Female',      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# ...

# %%
이게 스플릿이면 이제 어플라이 해야된당.
어플라이는 숫자 관련 애들만 바꿔주는것
이걸 컴바인!
S - A - C

# %%
tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
describe 는 기본적으로 숫자데이터만 보여준다

# %%
tips.describe(include='category')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
카테고리값으로 설정하면 다른 통계값을 보여준다!

# %%
tips.groupby('sex').count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Male           157  157     157  157   157   157
# Female          87   87      87   87    87    87

# %%
SAC 기법이 숨어있다

# %%
for i in tips.groupby(['sex','day']):
    print(i)
# Out:
# (('Male', 'Thur'),      total_bill   tip   sex smoker   day   time  size
# 77        27.20  4.00  Male     No  Thur  Lunch     4
# 78        22.76  3.00  Male     No  Thur  Lunch     2
# 79        17.29  2.71  Male     No  Thur  Lunch     2
# 80        19.44  3.00  Male    Yes  Thur  Lunch     2
# 81        16.66  3.40  Male     No  Thur  Lunch     2
# 83        32.68  5.00  Male    Yes  Thur  Lunch     2
# 84        15.98  2.03  Male     No  Thur  Lunch     2
# 86        13.03  2.00  Male     No  Thur  Lunch     2
# 87        18.28  4.00  Male     No  Thur  Lunch     2
# 88        24.71  5.85  Male     No  Thur  Lunch     2
# 89        21.16  3.00  Male     No  Thur  Lunch     2
# 120       11.69  2.31  Male     No  Thur  Lunch     2
# 122       14.26  2.50  Male     No  Thur  Lunch     2
# 123       15.95  2.00  Male     No  Thur  Lunch     2
# 126        8.52  1.48  Male     No  Thur  Lunch     2
# 129       22.82  2.18  Male     No  Thur  Lunch     3
# ...

# %%
tips.groupby(['sex','day']).mean()
# Out:
#              total_bill       tip      size
# sex    day
# Male   Thur   18.714667  2.980333  2.433333
#        Fri    19.857000  2.693000  2.100000
#        Sat    20.802542  3.083898  2.644068
#        Sun    21.887241  3.220345  2.810345
# Female Thur   16.715312  2.575625  2.468750
#        Fri    14.145556  2.781111  2.111111
#        Sat    19.680357  2.801786  2.250000
#        Sun    19.872222  3.367222  2.944444

# %%
tips.groupby(['sex','day']).mean().stack().reset_index()
# Out:
#        sex   day     level_2          0
# 0     Male  Thur  total_bill  18.714667
# 1     Male  Thur         tip   2.980333
# 2     Male  Thur        size   2.433333
# 3     Male   Fri  total_bill  19.857000
# 4     Male   Fri         tip   2.693000
# 5     Male   Fri        size   2.100000
# 6     Male   Sat  total_bill  20.802542
# 7     Male   Sat         tip   3.083898
# 8     Male   Sat        size   2.644068
# 9     Male   Sun  total_bill  21.887241
# 10    Male   Sun         tip   3.220345
# 11    Male   Sun        size   2.810345
# 12  Female  Thur  total_bill  16.715312
# 13  Female  Thur         tip   2.575625
# 14  Female  Thur        size   2.468750
# 15  Female   Fri  total_bill  14.145556
# 16  Female   Fri         tip   2.781111
# 17  Female   Fri        size   2.111111
# 18  Female   Sat  total_bill  19.680357
# 19  Female   Sat         tip   2.801786
# 20  Female   Sat        size   2.250000
# 21  Female   Sun  total_bill  19.872222
# ...

# %%
tips.groupby(['sex','day']).mean().unstack(1)
# Out:
#        total_bill                                        tip            \
# day          Thur        Fri        Sat        Sun      Thur       Fri
# sex
# Male    18.714667  19.857000  20.802542  21.887241  2.980333  2.693000
# Female  16.715312  14.145556  19.680357  19.872222  2.575625  2.781111
#
#                                 size
# day          Sat       Sun      Thur       Fri       Sat       Sun
# sex
# Male    3.083898  3.220345  2.433333  2.100000  2.644068  2.810345
# Female  2.801786  3.367222  2.468750  2.111111  2.250000  2.944444

# %%
우리가 원하는 모양으로 이렇게 데이터를 뚝딱뚝딱 만들수 있다

# %%
tips.groupby(['sex','day']).agg(['mean','std'])
# Out:
#             total_bill                  tip                size
#                   mean        std      mean       std      mean       std
# sex    day
# Male   Thur  18.714667   8.019728  2.980333  1.353734  2.433333  1.006302
#        Fri   19.857000  10.015847  2.693000  1.136428  2.100000  0.737865
#        Sat   20.802542   9.836306  3.083898  1.791360  2.644068  0.846142
#        Sun   21.887241   9.129142  3.220345  1.271172  2.810345  1.033762
# Female Thur  16.715312   7.759764  2.575625  1.109286  2.468750  1.135480
#        Fri   14.145556   4.788547  2.781111  0.938862  2.111111  0.333333
#        Sat   19.680357   8.806470  2.801786  1.234480  2.250000  0.700529
#        Sun   19.872222   7.837513  3.367222  1.136775  2.944444  0.937595

# %%
이렇게도 평균과 표준편차 한번에 보여주게 할수도 있따!

# %%
tips.groupby(['sex']).transform('sum')
# Out:
#      total_bill     tip  size
# 0       1570.95  246.51   214
# 1       3256.82  485.07   413
# 2       3256.82  485.07   413
# 3       3256.82  485.07   413
# 4       1570.95  246.51   214
# ..          ...     ...   ...
# 239     3256.82  485.07   413
# 240     1570.95  246.51   214
# 241     3256.82  485.07   413
# 242     3256.82  485.07   413
# 243     1570.95  246.51   214
#
# [244 rows x 3 columns]

# %%
tips.groupby(['sex']).transform(lambda x:x+1)
# Out:
#      total_bill   tip  size
# 0         17.99  2.01     3
# 1         11.34  2.66     4
# 2         22.01  4.50     4
# 3         24.68  4.31     3
# 4         25.59  4.61     5
# ..          ...   ...   ...
# 239       30.03  6.92     4
# 240       28.18  3.00     3
# 241       23.67  3.00     3
# 242       18.82  2.75     3
# 243       19.78  4.00     3
#
# [244 rows x 3 columns]

# %% [markdown]
# --------------------------
